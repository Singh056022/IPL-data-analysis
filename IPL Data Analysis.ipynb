# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'E:\Data Analysis\4-IPL data Analysis/deliveries.csv')

# %%
df.head(10)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
#
#    ball    batsman non_striker       bowler  is_super_over  ...  bye_runs  \
# ...

# %%
# Indepth analysis of David Warner performance
df_Warner = df[df['batsman']=='DA Warner']

# %%
df_Warner.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df_Warner['dismissal_kind'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='dismissal_kind'>

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
len(df_Warner[df_Warner['batsman_runs']==1])
# Out:
# 997

# %%
def count(df_Warner, runs):
    return len(df_Warner[df_Warner['batsman_runs']==runs])*runs

# %%
Run = [1,2,3,4,6]
Wa_run = []
for R in Run:
        Wa_run.append(count(df_Warner,R))
Wa_run
# Out:
# [997, 414, 39, 1604, 960]

# %%
explode = [0,0,0,0.1,0]

# %%
plt.pie(Wa_run, labels=Run, autopct = '%1.1f%%', explode = explode)
plt.title("DA Warner total runs contribution")
plt.tight_layout()
plt.show()

# %%
# Replacing team name with its abbreviation
df['batting_team'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Mumbai Indians', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants'],
#       dtype=object)

# %%
Teams = {'Sunrisers Hyderabad':'SRH', 'Royal Challengers Bangalore':'RCB',
       'Mumbai Indians':'MI', 'Rising Pune Supergiant':'RPS', 'Gujarat Lions':'GL',
       'Kolkata Knight Riders':'KKR', 'Kings XI Punjab':'KXIP', 'Delhi Daredevils':'DD',
       'Chennai Super Kings':'CSK', 'Rajasthan Royals':'RR', 'Deccan Chargers':'DC',
       'Kochi Tuskers Kerala':'KTK', 'Pune Warriors':'PW', 'Rising Pune Supergiants':'RPS'}

# %%
df['batting_team']= df['batting_team'].map(Teams)
df['bowling_team'] = df['bowling_team'].map(Teams)

# %%
df.head(10)
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0         1       1          SRH          RCB     1     1  DA Warner
# 1         1       1          SRH          RCB     1     2  DA Warner
# 2         1       1          SRH          RCB     1     3  DA Warner
# 3         1       1          SRH          RCB     1     4  DA Warner
# 4         1       1          SRH          RCB     1     5  DA Warner
# 5         1       1          SRH          RCB     1     6   S Dhawan
# 6         1       1          SRH          RCB     1     7   S Dhawan
# 7         1       1          SRH          RCB     2     1   S Dhawan
# 8         1       1          SRH          RCB     2     2  DA Warner
# 9         1       1          SRH          RCB     2     3  DA Warner
#
#   non_striker       bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan     TS Mills              0  ...         0            0
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
# Score distributions for teams by Innings
runs = df.groupby(['match_id','inning', 'batting_team'])['total_runs'].sum().reset_index()

# %%
runs.drop('match_id', axis =1, inplace = True)

# %%
runs.max()
# Out:
# inning            4
# batting_team    SRH
# total_runs      263
# dtype: object

# %%
inning1 = runs[runs['inning']==1]
inning2 = runs[runs['inning']==2]

# %%
inning1
# Out:
#       inning batting_team  total_runs
# 0          1          SRH         207
# 2          1           MI         184
# 4          1           GL         183
# 6          1          RPS         163
# 8          1          RCB         157
# ...      ...          ...         ...
# 1274       1           DD         138
# 1276       1           GL         158
# 1278       1          SRH         162
# 1280       1           GL         162
# 1282       1          SRH         208
#
# [636 rows x 3 columns]

# %%
plt.figure(figsize =(20,12))
sns.boxplot(x ='batting_team', y = 'total_runs', data = inning1)
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='total_runs'>

# %%
plt.figure(figsize =(20,12))
sns.boxplot(x ='batting_team', y = 'total_runs', data = inning2)
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='total_runs'>

# %%
#how many times teams scores more than 200
run_200 = df.groupby(['match_id','inning', 'batting_team','bowling_team'])['total_runs'].sum().reset_index()

# %%
high_200 = run_200[run_200['total_runs']>=200]

# %%
high_200
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1          SRH          RCB         207
# 16           9       1           DD          RPS         205
# 38          20       1          RCB           GL         213
# 62          32       1          SRH         KXIP         207
# 72          36       1          SRH          KKR         209
# ...        ...     ...          ...          ...         ...
# 1250       620       1          RCB           GL         248
# 1256       623       1           MI           DD         206
# 1262       626       1          RCB         KXIP         211
# 1282       636       1          SRH          RCB         208
# 1283       636       2          RCB          SRH         200
#
# [67 rows x 5 columns]

# %%
sns.countplot(high_200['batting_team'])
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='batting_team', ylabel='count'>

# %%
sns.countplot(high_200['bowling_team'])
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bowling_team', ylabel='count'>

# %%
#how many times team scores >200 runs against batting team
high=high_200.rename(columns={'total_runs':'count'})
high=high[high['count']>=200].groupby(['inning','batting_team','bowling_team']).count()
high.drop(['match_id'], axis = 1, inplace = True)

# %%
high
# Out:
#                                   count
# inning batting_team bowling_team
# 1      CSK          DD                1
#                     KKR               1
#                     KXIP              2
#                     MI                1
#                     RCB               1
#                     RR                1
#                     SRH               2
#        DC           RR                1
#        DD           KXIP              1
#                     MI                1
#                     RPS               1
#        GL           DD                1
#        KKR          DC                1
#                     KXIP              1
#                     RCB               1
#        KXIP         CSK               2
#                     MI                1
#                     RCB               2
#                     RR                1
#        MI           CSK               1
#                     DD                4
# ...

# %%
# Batsman comparison
Balls=df.groupby('batsman')['ball'].count().reset_index()

# %%
Balls
# Out:
#             batsman  ball
# 0    A Ashish Reddy   196
# 1        A Chandila     7
# 2          A Chopra    75
# 3       A Choudhary    20
# 4        A Flintoff    57
# ..              ...   ...
# 456     YV Takawale   183
# 457   Yashpal Singh    67
# 458     Younis Khan     7
# 459    Yuvraj Singh  2050
# 460          Z Khan   141
#
# [461 rows x 2 columns]

# %%
Runs = df.groupby('batsman')['batsman_runs'].sum().reset_index()
###Runs=df.groupby(['batsman'])['batsman_runs'].agg(sum).reset_index()

# %%
Runs.columns = ['batsman', 'runs']

# %%
Runs
# Out:
#             batsman  runs
# 0    A Ashish Reddy   280
# 1        A Chandila     4
# 2          A Chopra    53
# 3       A Choudhary    25
# 4        A Flintoff    62
# ..              ...   ...
# 456     YV Takawale   192
# 457   Yashpal Singh    47
# 458     Younis Khan     3
# 459    Yuvraj Singh  2591
# 460          Z Khan   117
#
# [461 rows x 2 columns]

# %%
Balls = Balls.merge(Runs, how ='outer')

# %%
Balls
# Out:
#             batsman  ball  runs
# 0    A Ashish Reddy   196   280
# 1        A Chandila     7     4
# 2          A Chopra    75    53
# 3       A Choudhary    20    25
# 4        A Flintoff    57    62
# ..              ...   ...   ...
# 456     YV Takawale   183   192
# 457   Yashpal Singh    67    47
# 458     Younis Khan     7     3
# 459    Yuvraj Singh  2050  2591
# 460          Z Khan   141   117
#
# [461 rows x 3 columns]

# %%
four = df[df['batsman_runs']==4]

# %%
four
# Out:
#         match_id  inning batting_team bowling_team  over  ball        batsman  \
# 2              1       1          SRH          RCB     1     3      DA Warner
# 8              1       1          SRH          RCB     2     2      DA Warner
# 13             1       1          SRH          RCB     2     7   MC Henriques
# 30             1       1          SRH          RCB     5     5   MC Henriques
# 32             1       1          SRH          RCB     6     1       S Dhawan
# ...          ...     ...          ...          ...   ...   ...            ...
# 150403       636       2          RCB          SRH    11     4        V Kohli
# 150407       636       2          RCB          SRH    12     2        V Kohli
# 150418       636       2          RCB          SRH    14     1       KL Rahul
# 150447       636       2          RCB          SRH    18     6    Sachin Baby
# 150459       636       2          RCB          SRH    20     6  Iqbal Abdulla
#
# ...

# %%
runs_4 = four.groupby('batsman')['batsman_runs'].count().reset_index()

# %%
runs_4.columns =['batsman','4s']
runs_4
# Out:
#             batsman   4s
# 0    A Ashish Reddy   16
# 1          A Chopra    7
# 2       A Choudhary    1
# 3        A Flintoff    5
# 4          A Kumble    3
# ..              ...  ...
# 363       YK Pathan  240
# 364     YV Takawale   26
# 365   Yashpal Singh    5
# 366    Yuvraj Singh  205
# 367          Z Khan   11
#
# [368 rows x 2 columns]

# %%
#six = df[df['batsman_runs']==6]
six=df.groupby('batsman')['batsman_runs'].agg(lambda x: (x==6).sum()).reset_index()

six.columns=['batsman','6s']
six.head(50)
# Out:
#             batsman   6s
# 0    A Ashish Reddy   15
# 1        A Chandila    0
# 2          A Chopra    0
# 3       A Choudhary    1
# 4        A Flintoff    2
# 5          A Kumble    0
# 6          A Mishra    5
# 7          A Mithun    1
# 8          A Mukund    0
# 9           A Nehra    1
# 10          A Singh    0
# 11        A Symonds   41
# 12         A Uniyal    0
# 13          A Zampa    0
# 14      AA Bilakhia    0
# 15        AA Chavan    0
# 16  AA Jhunjhunwala    5
# 17        AA Noffke    0
# 18       AB Agarkar    5
# 19        AB Barath    1
# 20         AB Dinda    0
# 21      AB McDonald    4
# 22   AB de Villiers  158
# 23      AC Blizzard    2
# 24     AC Gilchrist   92
# 25        AC Thomas    1
# 26         AC Voges    3
# 27   AD Mascarenhas    1
# 28       AD Mathews   29
# 29          AD Nath    0
# 30       AD Russell   37
# 31         AF Milne    0
# 32       AG Murtaza    0
# 33      AG Paunikar    0
# 34         AJ Finch   59
# 35           AJ Tye    3
# ...

# %%
player = pd.concat([Balls,runs_4.iloc[:,1],six.iloc[:,1]], axis =1)

# %%
player
# Out:
#             batsman  ball  runs    4s   6s
# 0    A Ashish Reddy   196   280  16.0   15
# 1        A Chandila     7     4   7.0    0
# 2          A Chopra    75    53   1.0    0
# 3       A Choudhary    20    25   5.0    1
# 4        A Flintoff    57    62   3.0    2
# ..              ...   ...   ...   ...  ...
# 456     YV Takawale   183   192   NaN    3
# 457   Yashpal Singh    67    47   NaN    0
# 458     Younis Khan     7     3   NaN    0
# 459    Yuvraj Singh  2050  2591   NaN  141
# 460          Z Khan   141   117   NaN    2
#
# [461 rows x 5 columns]

# %%
player['strike_rate']=(player['runs']/player['ball'])*100
player.head()
# Out:
#           batsman  ball  runs    4s  6s  strike_rate
# 0  A Ashish Reddy   196   280  16.0  15   142.857143
# 1      A Chandila     7     4   7.0   0    57.142857
# 2        A Chopra    75    53   1.0   0    70.666667
# 3     A Choudhary    20    25   5.0   1   125.000000
# 4      A Flintoff    57    62   3.0   2   108.771930

# %%
player.isnull().sum()
# Out:
# batsman         0
# ball            0
# runs            0
# 4s             93
# 6s              0
# strike_rate     0
# dtype: int64

# %%
player['4s'].fillna(0,inplace = True)

# %%
player
# Out:
#             batsman  ball  runs    4s   6s  strike_rate
# 0    A Ashish Reddy   196   280  16.0   15   142.857143
# 1        A Chandila     7     4   7.0    0    57.142857
# 2          A Chopra    75    53   1.0    0    70.666667
# 3       A Choudhary    20    25   5.0    1   125.000000
# 4        A Flintoff    57    62   3.0    2   108.771930
# ..              ...   ...   ...   ...  ...          ...
# 456     YV Takawale   183   192   0.0    3   104.918033
# 457   Yashpal Singh    67    47   0.0    0    70.149254
# 458     Younis Khan     7     3   0.0    0    42.857143
# 459    Yuvraj Singh  2050  2591   0.0  141   126.390244
# 460          Z Khan   141   117   0.0    2    82.978723
#
# [461 rows x 6 columns]

# %%
player.isnull().values.any()
# Out:
# False

# %%
#find maximum rate
grp = df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index()

# %%
grp
# Out:
#       match_id       batsman batting_team  batsman_runs
# 0            1   A Choudhary          RCB             6
# 1            1   BCJ Cutting          SRH            16
# 2            1      CH Gayle          RCB            32
# 3            1     DA Warner          SRH            14
# 4            1      DJ Hooda          SRH            16
# ...        ...           ...          ...           ...
# 9510       636     SR Watson          RCB            11
# 9511       636     STR Binny          RCB             9
# 9512       636   Sachin Baby          RCB            18
# 9513       636       V Kohli          RCB            54
# 9514       636  Yuvraj Singh          SRH            38
#
# [9515 rows x 4 columns]

# %%
Max=grp.groupby(['batsman'])['batsman_runs'].max().reset_index()
Max.columns=['batsman','max_runs']
Max
# Out:
#             batsman  max_runs
# 0    A Ashish Reddy        36
# 1        A Chandila         4
# 2          A Chopra        24
# 3       A Choudhary        15
# 4        A Flintoff        24
# ..              ...       ...
# 456     YV Takawale        45
# 457   Yashpal Singh        20
# 458     Younis Khan         3
# 459    Yuvraj Singh        83
# 460          Z Khan        23
#
# [461 rows x 2 columns]

# %%
player = pd.concat([player,Max.iloc[:,1]], axis = 1)

# %%
player
# Out:
#             batsman  ball  runs    4s   6s  strike_rate  max_runs
# 0    A Ashish Reddy   196   280  16.0   15   142.857143        36
# 1        A Chandila     7     4   7.0    0    57.142857         4
# 2          A Chopra    75    53   1.0    0    70.666667        24
# 3       A Choudhary    20    25   5.0    1   125.000000        15
# 4        A Flintoff    57    62   3.0    2   108.771930        24
# ..              ...   ...   ...   ...  ...          ...       ...
# 456     YV Takawale   183   192   0.0    3   104.918033        45
# 457   Yashpal Singh    67    47   0.0    0    70.149254        20
# 458     Younis Khan     7     3   0.0    0    42.857143         3
# 459    Yuvraj Singh  2050  2591   0.0  141   126.390244        83
# 460          Z Khan   141   117   0.0    2    82.978723        23
#
# [461 rows x 7 columns]

# %%
# Top 10 players from entire season
Max_runs = df.groupby('batsman')['batsman_runs'].sum().sort_values(ascending = False)[:10].plot(kind = 'bar')

# %%
# Top individual scores by team
df.groupby(["match_id","batsman",'batting_team'])["batsman_runs"].sum().reset_index().sort_values(by='batsman_runs', ascending=False).head(10)
# Out:
#       match_id         batsman batting_team  batsman_runs
# 6200       411        CH Gayle          RCB           175
# 900         60     BB McCullum          KKR           158
# 8426       562  AB de Villiers          RCB           133
# 9257       620  AB de Villiers          RCB           129
# 5585       372        CH Gayle          RCB           128
# 3135       206         M Vijay          CSK           127
# 529         36       DA Warner          SRH           126
# 7752       516        V Sehwag         KXIP           122
# 3686       243     PC Valthaty         KXIP           120
# 4223       279        V Sehwag           DD           119

# %%
# highest wicket taker
df['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
dismissal_kinds =['caught', 'bowled', 'lbw', 'caught and bowled',
       'stumped', 'hit wicket']

# %%
by_bowler = df[df['dismissal_kind'].isin(dismissal_kinds)]

# %%
by_bowler
# Out:
#         match_id  inning batting_team bowling_team  over  ball  \
# 11             1       1          SRH          RCB     2     5
# 64             1       1          SRH          RCB    11     3
# 94             1       1          SRH          RCB    16     2
# 116            1       1          SRH          RCB    19     4
# 160            1       2          RCB          SRH     6     4
# ...          ...     ...          ...          ...   ...   ...
# 150402       636       2          RCB          SRH    11     3
# 150416       636       2          RCB          SRH    13     5
# 150422       636       2          RCB          SRH    14     5
# 150432       636       2          RCB          SRH    16     3
# 150438       636       2          RCB          SRH    17     3
#
#                batsman     non_striker             bowler  is_super_over  ...  \
# 11           DA Warner        S Dhawan        A Choudhary              0  ...
# ...

# %%
by_bowler['bowler'].value_counts()[:10].plot.bar()
# Out:
# <AxesSubplot:>
